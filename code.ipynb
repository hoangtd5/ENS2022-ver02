# %% [markdown]
# ## Power generation Forecasting
# by Hoang cute

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import tensorflow as tf
import warnings
warnings.simplefilter(action='ignore', category=(FutureWarning, UserWarning))
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# Read the datasets
import glob
path = r'.\dataset\weatherdata' # use your path
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0,encoding = 'unicode_escape')
    df = df.rename(columns={'ÁöÁ¡':'Point','ÀÏ½Ã':'datetime','±â¿Â(¡ÆC)':'Temperature (°C)','´©Àû°­¼ö·®(mm)':'Precipitation (mm)','Ç³Çâ(deg)':'Wind Direction (deg)'
    ,'Ç³¼Ó(m/s)':'Wind Speed ​​(m/s)','ÇöÁö±â¾Ð(hPa)':'Barometric Pressure (hPa)','ÇØ¸é±â¾Ð(hPa)':'Sea Level Pressure (hPa)','½Àµµ(%)':'Humidity (%)',
    'ÀÏ»ç(MJ/m^2)':'Insolation (MJ/m^2)','ÀÏÁ¶(Sec)':'Sunlight (Sec)'})
    df['datetime'] = pd.to_datetime(df['datetime'])
    li.append(df)

df_weather = pd.concat(li, axis=0, ignore_index=True)
df_weather = df_weather.drop_duplicates(keep=False)
df_weather = df_weather.drop(['Point'],axis=1).set_index('datetime')
df_weather.head()
# Out:
#                      Temperature (°C)  Precipitation (mm)  \
# datetime
# 2021-01-01 00:01:00              -4.2                 0.0
# 2021-01-01 00:02:00              -4.1                 0.0
# 2021-01-01 00:03:00              -4.0                 0.0
# 2021-01-01 00:04:00              -4.1                 0.0
# 2021-01-01 00:05:00              -4.1                 0.0
#
#                      Wind Direction (deg)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:01:00                 323.6                 5.1
# 2021-01-01 00:02:00                 315.7                 5.7
# 2021-01-01 00:03:00                 308.5                 4.6
# 2021-01-01 00:04:00                 305.5                 5.3
# 2021-01-01 00:05:00                 309.0                 4.8
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2021-01-01 00:01:00                     1020.5                    1025.7
# 2021-01-01 00:02:00                     1020.5                    1025.7
# 2021-01-01 00:03:00                     1020.5                    1025.7
# 2021-01-01 00:04:00                     1020.6                    1025.8
# 2021-01-01 00:05:00                     1020.6                    1025.8
#
#                      Humidity (%)  Insolation (MJ/m^2)  Sunlight (Sec)
# datetime
# 2021-01-01 00:01:00          59.7                  0.0             0.0
# 2021-01-01 00:02:00          58.3                  0.0             0.0
# 2021-01-01 00:03:00          58.1                  0.0             0.0
# 2021-01-01 00:04:00          58.5                  0.0             0.0
# 2021-01-01 00:05:00          58.8                  0.0             0.0

# %%
print(len(df_weather))
# Out:
# 738228

# %%
davg_hourly = df_weather.resample('H').median()
davg_solar_last = df_weather[['Insolation (MJ/m^2)','Sunlight (Sec)']].resample('H').last()
davg_solar_first = df_weather[['Insolation (MJ/m^2)','Sunlight (Sec)']].resample('H').first()
davg_solar = davg_solar_last.subtract(davg_solar_first,fill_value=0).rename(columns={'Insolation (MJ/m^2)':'Insolation (MJ/m^2) per hour','Sunlight (Sec)':'Sunlight (Sec) per hour'})
davg_solar[davg_solar<0] = 0
fr_weather = pd.merge(davg_hourly,davg_solar,left_index=True,right_index=True).drop(['Insolation (MJ/m^2)','Sunlight (Sec)'],axis=1)
fr_weather = fr_weather.reset_index()
fr_weather = fr_weather[(fr_weather.datetime < '2022-01-01 00:00:00') | (fr_weather.datetime >= '2022-02-01 00:00:00')].set_index('datetime')

fr_weather.head()
# Out:
#                      Temperature (°C)  Precipitation (mm)  \
# datetime
# 2021-01-01 00:00:00              -4.3                 0.0
# 2021-01-01 01:00:00              -4.8                 0.0
# 2021-01-01 02:00:00              -5.2                 0.0
# 2021-01-01 03:00:00              -5.1                 0.0
# 2021-01-01 04:00:00              -4.8                 0.0
#
#                      Wind Direction (deg)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:00:00                317.30                4.70
# 2021-01-01 01:00:00                329.20                3.60
# 2021-01-01 02:00:00                335.50                3.15
# 2021-01-01 03:00:00                330.95                4.05
# 2021-01-01 04:00:00                324.65                4.05
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2021-01-01 00:00:00                    1020.90                   1026.10
# 2021-01-01 01:00:00                    1020.80                   1026.00
# 2021-01-01 02:00:00                    1020.80                   1026.00
# 2021-01-01 03:00:00                    1021.40                   1026.60
# 2021-01-01 04:00:00                    1021.45                   1026.65
#
#                      Humidity (%)  Insolation (MJ/m^2) per hour  \
# datetime
# 2021-01-01 00:00:00         57.00                           0.0
# 2021-01-01 01:00:00         57.05                           0.0
# 2021-01-01 02:00:00         59.35                           0.0
# 2021-01-01 03:00:00         60.45                           0.0
# 2021-01-01 04:00:00         59.30                           0.0
#
#                      Sunlight (Sec) per hour
# datetime
# 2021-01-01 00:00:00                      0.0
# 2021-01-01 01:00:00                      0.0
# 2021-01-01 02:00:00                      0.0
# 2021-01-01 03:00:00                      0.0
# 2021-01-01 04:00:00                      0.0

# %%
print(len(davg_hourly))
print(len(davg_solar_last))
print(len(davg_solar_first))
print(len(fr_weather))
# Out:
# 13104
# 13104
# 13104
# 12360

# %%
fr_weather.head()
# Out:
#                      Temperature (°C)  Precipitation (mm)  \
# datetime
# 2021-01-01 00:00:00              -4.3                 0.0
# 2021-01-01 01:00:00              -4.8                 0.0
# 2021-01-01 02:00:00              -5.2                 0.0
# 2021-01-01 03:00:00              -5.1                 0.0
# 2021-01-01 04:00:00              -4.8                 0.0
#
#                      Wind Direction (deg)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:00:00                317.30                4.70
# 2021-01-01 01:00:00                329.20                3.60
# 2021-01-01 02:00:00                335.50                3.15
# 2021-01-01 03:00:00                330.95                4.05
# 2021-01-01 04:00:00                324.65                4.05
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2021-01-01 00:00:00                    1020.90                   1026.10
# 2021-01-01 01:00:00                    1020.80                   1026.00
# 2021-01-01 02:00:00                    1020.80                   1026.00
# 2021-01-01 03:00:00                    1021.40                   1026.60
# 2021-01-01 04:00:00                    1021.45                   1026.65
#
#                      Humidity (%)  Insolation (MJ/m^2) per hour  \
# datetime
# 2021-01-01 00:00:00         57.00                           0.0
# 2021-01-01 01:00:00         57.05                           0.0
# 2021-01-01 02:00:00         59.35                           0.0
# 2021-01-01 03:00:00         60.45                           0.0
# 2021-01-01 04:00:00         59.30                           0.0
#
#                      Sunlight (Sec) per hour
# datetime
# 2021-01-01 00:00:00                      0.0
# 2021-01-01 01:00:00                      0.0
# 2021-01-01 02:00:00                      0.0
# 2021-01-01 03:00:00                      0.0
# 2021-01-01 04:00:00                      0.0

# %%
fr_weather.to_csv('Gyeongjusi_hourly.csv')

# %%
# Read the datasets
import glob
path = r'.\dataset\ensdata' # use your path
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df_energy = pd.concat(li, axis=0, ignore_index=True)
df_energy = df_energy[pd.to_numeric(df_energy['Hour'], errors='coerce').notnull()]
#df_energy = df_energy.drop_duplicates(keep=False)
df_energy['datetime'] = pd.to_datetime(df_energy['Date'] + ' ' + df_energy['Hour'] + ':00:00')
df_energy = df_energy.drop(['Date','Hour'],axis=1).set_index('datetime')
df_energy.head()
# Out:
#                     P(kWh)    h_max
# datetime
# 2021-01-01 00:00:00      0  33391.0
# 2021-01-01 01:00:00      0  33391.0
# 2021-01-01 02:00:00      0  33391.0
# 2021-01-01 03:00:00      0  33391.0
# 2021-01-01 04:00:00      0  33391.0

# %%
print(len(df_energy))
# Out:
# 12203

# %%
def df_convert_dtypes(df, convert_from, convert_to):
    cols = df.select_dtypes(include=[convert_from]).columns
    for col in cols:
        df[col] = df[col].values.astype(convert_to)
    return df

# %%
df_merge = pd.merge(
    fr_weather,
    df_energy,
    how="outer",
    on="datetime",
    sort=True
)
df_merge = df_convert_dtypes(df_merge, np.object, np.float64)
df_merge.head(30)
# Out:
#                      Temperature (°C)  Precipitation (mm)  \
# datetime
# 2021-01-01 00:00:00             -4.30                 0.0
# 2021-01-01 01:00:00             -4.80                 0.0
# 2021-01-01 02:00:00             -5.20                 0.0
# 2021-01-01 03:00:00             -5.10                 0.0
# 2021-01-01 04:00:00             -4.80                 0.0
# 2021-01-01 05:00:00             -4.80                 0.0
# 2021-01-01 06:00:00             -5.20                 0.0
# 2021-01-01 07:00:00             -9.00                 0.0
# 2021-01-01 08:00:00             -7.45                 0.0
# 2021-01-01 09:00:00             -4.05                 0.0
# 2021-01-01 10:00:00             -2.00                 0.0
# 2021-01-01 11:00:00             -0.30                 0.0
# 2021-01-01 12:00:00              1.00                 0.0
# 2021-01-01 13:00:00              2.40                 0.0
# 2021-01-01 14:00:00              2.20                 0.0
# 2021-01-01 15:00:00              2.90                 0.0
# 2021-01-01 16:00:00              2.30                 0.0
# 2021-01-01 17:00:00              1.40                 0.0
# 2021-01-01 18:00:00             -0.30                 0.0
# 2021-01-01 19:00:00             -1.40                 0.0
# 2021-01-01 20:00:00             -1.60                 0.0
# 2021-01-01 21:00:00             -2.40                 0.0
# 2021-01-01 22:00:00             -3.40                 0.0
# 2021-01-01 23:00:00             -4.55                 0.0
# 2021-01-02 00:00:00             -5.75                 0.0
# 2021-01-02 01:00:00             -6.30                 0.0
# 2021-01-02 02:00:00             -5.40                 0.0
# 2021-01-02 03:00:00             -4.80                 0.0
# 2021-01-02 04:00:00             -4.90                 0.0
# 2021-01-02 05:00:00             -5.50                 0.0
#
#                      Wind Direction (deg)  Wind Speed ​​(m/s)  \
# datetime
# 2021-01-01 00:00:00                317.30                4.70
# 2021-01-01 01:00:00                329.20                3.60
# 2021-01-01 02:00:00                335.50                3.15
# 2021-01-01 03:00:00                330.95                4.05
# 2021-01-01 04:00:00                324.65                4.05
# 2021-01-01 05:00:00                334.55                4.90
# 2021-01-01 06:00:00                272.65                3.10
# 2021-01-01 07:00:00                177.20                2.95
# 2021-01-01 08:00:00                191.20                3.20
# 2021-01-01 09:00:00                168.20                1.10
# 50%           14.700000            0.000000            187.850000
# 75%           21.750000            0.000000            271.662500
# max           36.300000           89.300000            355.350000
#
#        Wind Speed ​​(m/s)  Barometric Pressure (hPa)  \
# count        12318.000000               12330.000000
# mean             2.594804                1011.578990
# std              1.637471                   7.534894
# min              0.000000                 991.400000
# 25%              1.300000                1006.000000
# 50%              2.200000                1011.800000
# 75%              3.700000                1017.200000
# max             11.250000                1031.900000
#
#        Sea Level Pressure (hPa)  Humidity (%)  Insolation (MJ/m^2) per hour  \
# count              12330.000000  12330.000000                  12330.000000
# mean                1016.386322     66.052685                      0.649091
# std                    7.698338     23.865162                      0.955693
# min                  995.900000      7.750000                      0.000000
# 25%                 1010.700000     46.900000                      0.000000
# 50%                 1016.600000     69.850000                      0.030000
# 75%                 1022.100000     88.150000                      1.120000
# max                 1037.100000     98.600000                      4.250000
#
#        Sunlight (Sec) per hour        P(kWh)          h_max
# count             12330.000000  12203.000000   12203.000000
# mean                948.211192     17.366058  141367.293207
# std                1446.187853     26.115148   64488.044027
# min                   0.000000      0.000000   33391.000000
# 25%                   0.000000      0.000000   88264.000000
# 50%                   0.000000      1.000000  139544.000000
# 75%                2217.000000     29.000000  197295.000000
# max                6192.000000    172.000000  259530.000000

# %%
# Define a function to plot different types of time-series

def plot_series(df=None, column=None, series=pd.Series([]), 
                label=None, ylabel=None, title=None, start=0, end=None):
    """
    Plots a certain time-series which has either been loaded in a dataframe
    and which constitutes one of its columns or it a custom pandas series 
    created by the user. The user can define either the 'df' and the 'column' 
    or the 'series' and additionally, can also define the 'label', the 
    'ylabel', the 'title', the 'start' and the 'end' of the plot.
    """
    sns.set()
    fig, ax = plt.subplots(figsize=(30, 12))
    ax.set_xlabel('Time', fontsize=16)
    if column:
        ax.plot(df[column][start:end], label=label)
        ax.set_ylabel(ylabel, fontsize=16)
    if series.any():
        ax.plot(series, label=label)
        ax.set_ylabel(ylabel, fontsize=16)
    if label:
        ax.legend(fontsize=16)
    if title:
        ax.set_title(title, fontsize=24)
    ax.grid(True)
    return ax
    # Zoom into the plot of the hourly (actual) total load

ax = plot_series(df=df_merge, column='P(kWh)', ylabel='Total Power (kWh)',
                 title='Actual Total Power Generation (First 2 weeks - Original)', end=24*7*2)
plt.show()

# %%
# Display the rows with null values

df_merge[df_merge.isnull().any(axis=1)].tail()
# Out:
#                      Temperature (°C)  Precipitation (mm)  \
# datetime
# 2022-04-11 19:00:00             19.15                 NaN
# 2022-04-11 20:00:00             18.40                 NaN
# 2022-04-11 21:00:00             17.70                 NaN
# 2022-04-11 22:00:00             17.10                 NaN
# 2022-04-11 23:00:00             16.70                 NaN
#
#                      Wind Direction (deg)  Wind Speed ​​(m/s)  \
# datetime
# 2022-04-11 19:00:00                192.05                4.55
# 2022-04-11 20:00:00                186.65                3.75
# 2022-04-11 21:00:00                198.55                2.80
# 2022-04-11 22:00:00                203.30                3.70
# 2022-04-11 23:00:00                186.60                2.20
#
#                      Barometric Pressure (hPa)  Sea Level Pressure (hPa)  \
# datetime
# 2022-04-11 19:00:00                     1007.0                    1011.7
# 2022-04-11 20:00:00                     1007.8                    1012.5
# 2022-04-11 21:00:00                     1008.3                    1013.0
# 2022-04-11 22:00:00                     1008.2                    1012.9
# 2022-04-11 23:00:00                     1008.4                    1013.1
#
#                      Humidity (%)  Insolation (MJ/m^2) per hour  \
# datetime
# 2022-04-11 19:00:00         74.15                           0.0
# 2022-04-11 20:00:00         77.00                           0.0
# 2022-04-11 21:00:00         79.00                           0.0
# 2022-04-11 22:00:00         81.60                           0.0
# 2022-04-11 23:00:00         82.80                           0.0
#
#                      Sunlight (Sec) per hour  P(kWh)     h_max
# datetime
# 2022-04-11 19:00:00                      0.0     0.0  218922.0
# 2022-04-11 20:00:00                      0.0     0.0  218922.0
# 2022-04-11 21:00:00                      0.0     0.0  218922.0
# 2022-04-11 22:00:00                      0.0     0.0  218922.0
# 2022-04-11 23:00:00                      0.0     0.0  218922.0

# %%
# Fill null values using interpolation

df_merge.interpolate(method='linear', limit_direction='forward', inplace=True, axis=0)

# %%
# Display the number of non-zero values in each column

print('Non-zero values in each column:\n', df_merge.astype(bool).sum(axis=0), sep='\n')
# Out:
# Non-zero values in each column:
#
# Temperature (°C)                12337
# Precipitation (mm)               2200
# Wind Direction (deg)            12317
# Wind Speed ​​(m/s)              12317
# Barometric Pressure (hPa)       12360
# Sea Level Pressure (hPa)        12360
# Humidity (%)                    12360
# Insolation (MJ/m^2) per hour     6606
# Sunlight (Sec) per hour          4560
# P(kWh)                           6281
# h_max                           12360
# dtype: int64

# %%
# Check for outliers in 'pressure' column

sns.boxplot(x=df_merge['Temperature (°C)'])
plt.show()

# %%
# Plot the 'rain_1h' for Bilbao
rolling = df_merge['P(kWh)'].rolling(24*7, center=True).mean()

ax = plot_series(df_merge, 'P(kWh)', 
                 label='Hourly', ylabel='Actual Power Generation (kWh)',
                 title='Power generation in Gyeongju-si')
ax.plot(rolling, linestyle='-', linewidth=2, label='Weekly rolling mean')

plt.show()

# %% [markdown]
# ## <a id='ref14'>2.3. Autocorrelation, partial autocorrelation and cross-correlation</a>

# %%
# Plot autocorrelation and partial autocorrelation plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(10, 6))
plot_acf(df_merge['P(kWh)'], lags=50, ax=ax1)
plot_pacf(df_merge['P(kWh)'], lags=50, ax=ax2)
plt.tight_layout()
plt.show()

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12360 entries, 2021-01-01 00:00:00 to 2022-06-30 23:00:00
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Temperature (°C)              12360 non-null  float64
#  1   Precipitation (mm)            12360 non-null  float64
#  2   Wind Direction (deg)          12360 non-null  float64
#  3   Wind Speed ​​(m/s)            12360 non-null  float64
#  4   Barometric Pressure (hPa)     12360 non-null  float64
#  5   Sea Level Pressure (hPa)      12360 non-null  float64
#  6   Humidity (%)                  12360 non-null  float64
#  7   Insolation (MJ/m^2) per hour  12360 non-null  float64
#  8   Sunlight (Sec) per hour       12360 non-null  float64
#  9   P(kWh)                        12360 non-null  float64
#  10  h_max                         12360 non-null  float64
# dtypes: float64(11)
# memory usage: 1.1 MB

# %%
# Find the correlations between the electricity price and the rest of the features

correlations = df_merge.corr(method='pearson')
print(correlations.columns)
print(correlations['P(kWh)'].sort_values(ascending=False).to_string())
# Out:
# Index(['Temperature (°C)', 'Precipitation (mm)', 'Wind Direction (deg)',
#        'Wind Speed ​​(m/s)', 'Barometric Pressure (hPa)',
#        'Sea Level Pressure (hPa)', 'Humidity (%)',
#        'Insolation (MJ/m^2) per hour', 'Sunlight (Sec) per hour', 'P(kWh)',
#        'h_max'],
#       dtype='object')
# P(kWh)                          1.000000
# Insolation (MJ/m^2) per hour    0.939271
# Sunlight (Sec) per hour         0.806311
# Wind Speed ​​(m/s)              0.295803
# Temperature (°C)                0.265112
# Wind Direction (deg)            0.086512
# h_max                           0.035325
# Barometric Pressure (hPa)      -0.010425
# Sea Level Pressure (hPa)       -0.016479
# Precipitation (mm)             -0.092167
# Humidity (%)                   -0.548498

# %%
# Plot Pearson correlation matrix

correlations = df_merge.corr(method='pearson')
fig = plt.figure(figsize=(15, 12))
sns.heatmap(correlations, annot=True, fmt='.2f')
plt.title('Pearson Correlation Matrix')
plt.show()

# %%
highly_correlated = abs(correlations[correlations > 0.75])
print(highly_correlated[highly_correlated < 1.0].stack().to_string())
# Out:
# Barometric Pressure (hPa)     Sea Level Pressure (hPa)        0.999837
# Sea Level Pressure (hPa)      Barometric Pressure (hPa)       0.999837
# Insolation (MJ/m^2) per hour  Sunlight (Sec) per hour         0.842034
#                               P(kWh)                          0.939271
# Sunlight (Sec) per hour       Insolation (MJ/m^2) per hour    0.842034
#                               P(kWh)                          0.806311
# P(kWh)                        Insolation (MJ/m^2) per hour    0.939271
#                               Sunlight (Sec) per hour         0.806311

# %% [markdown]
# ## <a id='ref17'>Feature selection</a>

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size
        
    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])
        
        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i : i + target_size])

    return np.array(data), np.array(labels)

# %%
train_end_idx = 8760
cv_end_idx = 10176
test_end_idx = 12000

# %%
df_final  = df_merge.copy()
# Wind Direction (deg)            0.086512
# h_max                           0.035325
# Barometric Pressure (hPa)      -0.010425
# Sea Level Pressure (hPa)       -0.016479
# Precipitation (mm)             -0.092167
# Humidity (%)                   -0.548498
X = df_final[df_final.columns.drop(['P(kWh)','Wind Direction (deg)','h_max','Barometric Pressure (hPa)','Sea Level Pressure (hPa)','Precipitation (mm)'])].values
y = df_final['P(kWh)'].values

y = y.reshape(-1, 1)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# %%
scaler_X.fit(X[:train_end_idx])
scaler_y.fit(y[:train_end_idx])
# Out:
# MinMaxScaler()

# %%
X_norm = scaler_X.transform(X)
y_norm = scaler_y.transform(y)

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_pca = pca.fit(X_norm[:train_end_idx])

# %%
num_components = len(pca.explained_variance_ratio_)
plt.figure(figsize=(10, 6))
plt.bar(np.arange(num_components), pca.explained_variance_ratio_)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Principal component')
plt.ylabel('Explained variance')
plt.show()

# %%
pca = PCA(n_components=0.95)
pca.fit(X_norm[:train_end_idx])
X_pca = pca.transform(X_norm)

# %%
X_pca.shape
# Out:
# (12360, 4)

# %%
dataset_norm = np.concatenate((X_pca, y_norm), axis=1)

past_history = 12
future_target = 0

# %%
X_train, y_train = multivariate_data(dataset_norm, dataset_norm[:, -1],
                                     0, train_end_idx, past_history, 
                                     future_target, step=1, single_step=True)

# %%
X_val, y_val = multivariate_data(dataset_norm, dataset_norm[:, -1],
                                 train_end_idx, cv_end_idx, past_history, 
                                 future_target, step=1, single_step=True)

# %%
X_test, y_test = multivariate_data(dataset_norm, dataset_norm[:, -1],
                                   cv_end_idx, test_end_idx, past_history, 
                                   future_target, step=1, single_step=True)

# %%
batch_size = 16
buffer_size = 1000

# %%
train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train = train.cache().shuffle(buffer_size).batch(batch_size).prefetch(1)

validation = tf.data.Dataset.from_tensor_slices((X_val, y_val))
validation = validation.batch(batch_size).prefetch(1)

# %%
# Define some common parameters

input_shape = X_train.shape[-2:]
loss = tf.keras.losses.MeanSquaredError()
metric = [tf.keras.metrics.RootMeanSquaredError()]
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
              lambda epoch: 1e-4 * 10**(epoch / 10))
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10)

# %%
y_test = y_test.reshape(-1, 1)

y_test_inv = scaler_y.inverse_transform(y_test)

# %%
def plot_model_rmse_and_loss(history):
    
    # Evaluate train and validation accuracies and losses
    
    train_rmse = history.history['root_mean_squared_error']
    val_rmse = history.history['val_root_mean_squared_error']
    
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    # Visualize epochs vs. train and validation accuracies and losses
    
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.plot(train_rmse, label='Training RMSE')
    plt.plot(val_rmse, label='Validation RMSE')
    plt.legend()
    plt.title('Epochs vs. Training and Validation RMSE')
    
    plt.subplot(1, 2, 2)
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend()
    plt.title('Epochs vs. Training and Validation Loss')
    
    plt.show()

# %% [markdown]
# ## 1. XG Boost

# %%
X_train_xgb = X_train.reshape(-1, X_train.shape[1] * X_train.shape[2])
X_val_xgb = X_val.reshape(-1, X_val.shape[1] * X_val.shape[2])
X_test_xgb = X_test.reshape(-1, X_test.shape[1] * X_test.shape[2])

# %%
X_train_xgb.shape
# Out:
# (8748, 60)

# %%
import xgboost as xgb

param = {'eta': 0.03, 'max_depth': 180, 
         'subsample': 1.0, 'colsample_bytree': 0.95, 
         'alpha': 0.1, 'lambda': 0.15, 'gamma': 0.1,
         'objective': 'reg:linear', 'eval_metric': 'rmse', 
         'silent': 1, 'min_child_weight': 0.1, 'n_jobs': -1}

dtrain = xgb.DMatrix(X_train_xgb, y_train)
dval = xgb.DMatrix(X_val_xgb, y_val)
dtest = xgb.DMatrix(X_test_xgb, y_test)
eval_list = [(dtrain, 'train'), (dval, 'eval')]

xgb_model = xgb.train(param, dtrain, 300, eval_list, early_stopping_rounds=3)
# Out:
# [13:12:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:12:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:0.41925	eval-rmse:0.41427
# [1]	train-rmse:0.40681	eval-rmse:0.40199
# [2]	train-rmse:0.39473	eval-rmse:0.39010
# [3]	train-rmse:0.38302	eval-rmse:0.37853
# [4]	train-rmse:0.37166	eval-rmse:0.36734
# [5]	train-rmse:0.36065	eval-rmse:0.35651
# [6]	train-rmse:0.34997	eval-rmse:0.34600
# [7]	train-rmse:0.33961	eval-rmse:0.33577
# [8]	train-rmse:0.32957	eval-rmse:0.32587
# [9]	train-rmse:0.31983	eval-rmse:0.31625
# [10]	train-rmse:0.31043	eval-rmse:0.30696
# [11]	train-rmse:0.30127	eval-rmse:0.29791
# [12]	train-rmse:0.29239	eval-rmse:0.28915
# [13]	train-rmse:0.28379	eval-rmse:0.28067
# [14]	train-rmse:0.27544	eval-rmse:0.27240
# [15]	train-rmse:0.26735	eval-rmse:0.26442
# [16]	train-rmse:0.25950	eval-rmse:0.25667
# [17]	train-rmse:0.25189	eval-rmse:0.24915
# [18]	train-rmse:0.24451	eval-rmse:0.24189
# [19]	train-rmse:0.23736	eval-rmse:0.23482
# [20]	train-rmse:0.23043	eval-rmse:0.22798
# [21]	train-rmse:0.22371	eval-rmse:0.22135
# [22]	train-rmse:0.21719	eval-rmse:0.21494
# [23]	train-rmse:0.21090	eval-rmse:0.20868
# [24]	train-rmse:0.20477	eval-rmse:0.20263
# [25]	train-rmse:0.19884	eval-rmse:0.19674
# [26]	train-rmse:0.19309	eval-rmse:0.19108
# [83]	train-rmse:0.04842	eval-rmse:0.04651
# [84]	train-rmse:0.04771	eval-rmse:0.04575
# [85]	train-rmse:0.04704	eval-rmse:0.04506
# [86]	train-rmse:0.04639	eval-rmse:0.04441
# [87]	train-rmse:0.04576	eval-rmse:0.04375
# [88]	train-rmse:0.04518	eval-rmse:0.04315
# [89]	train-rmse:0.04461	eval-rmse:0.04256
# [90]	train-rmse:0.04410	eval-rmse:0.04202
# [91]	train-rmse:0.04358	eval-rmse:0.04148
# [92]	train-rmse:0.04310	eval-rmse:0.04096
# [93]	train-rmse:0.04265	eval-rmse:0.04048
# [94]	train-rmse:0.04222	eval-rmse:0.04005
# [95]	train-rmse:0.04180	eval-rmse:0.03959
# [96]	train-rmse:0.04139	eval-rmse:0.03917
# [97]	train-rmse:0.04101	eval-rmse:0.03874
# [98]	train-rmse:0.04064	eval-rmse:0.03837
# [99]	train-rmse:0.04029	eval-rmse:0.03800
# [100]	train-rmse:0.03996	eval-rmse:0.03766
# [101]	train-rmse:0.03967	eval-rmse:0.03735
# [102]	train-rmse:0.03939	eval-rmse:0.03706
# [103]	train-rmse:0.03912	eval-rmse:0.03677
# [104]	train-rmse:0.03887	eval-rmse:0.03651
# [105]	train-rmse:0.03862	eval-rmse:0.03623
# [106]	train-rmse:0.03837	eval-rmse:0.03598
# [107]	train-rmse:0.03813	eval-rmse:0.03573
# [108]	train-rmse:0.03792	eval-rmse:0.03551
# [109]	train-rmse:0.03769	eval-rmse:0.03528
# [110]	train-rmse:0.03751	eval-rmse:0.03508
# [111]	train-rmse:0.03731	eval-rmse:0.03486
# [112]	train-rmse:0.03714	eval-rmse:0.03468
# [113]	train-rmse:0.03696	eval-rmse:0.03450
# [114]	train-rmse:0.03681	eval-rmse:0.03433
# [115]	train-rmse:0.03663	eval-rmse:0.03415
# [116]	train-rmse:0.03648	eval-rmse:0.03399
# [117]	train-rmse:0.03633	eval-rmse:0.03384
# [118]	train-rmse:0.03618	eval-rmse:0.03368
# [119]	train-rmse:0.03606	eval-rmse:0.03357
# [120]	train-rmse:0.03589	eval-rmse:0.03343
# [121]	train-rmse:0.03578	eval-rmse:0.03332
# [122]	train-rmse:0.03566	eval-rmse:0.03320
# [123]	train-rmse:0.03557	eval-rmse:0.03311
# [124]	train-rmse:0.03549	eval-rmse:0.03302
# [125]	train-rmse:0.03538	eval-rmse:0.03291
# [126]	train-rmse:0.03529	eval-rmse:0.03281
# [127]	train-rmse:0.03522	eval-rmse:0.03273
# [128]	train-rmse:0.03515	eval-rmse:0.03265
# [129]	train-rmse:0.03509	eval-rmse:0.03259
# [130]	train-rmse:0.03504	eval-rmse:0.03254
# [131]	train-rmse:0.03499	eval-rmse:0.03248
# [132]	train-rmse:0.03495	eval-rmse:0.03243
# [133]	train-rmse:0.03490	eval-rmse:0.03239
# [134]	train-rmse:0.03486	eval-rmse:0.03235
# [135]	train-rmse:0.03483	eval-rmse:0.03231
# [136]	train-rmse:0.03479	eval-rmse:0.03227
# [137]	train-rmse:0.03476	eval-rmse:0.03223
# [193]	train-rmse:0.03416	eval-rmse:0.03161
# [194]	train-rmse:0.03416	eval-rmse:0.03160
# [195]	train-rmse:0.03416	eval-rmse:0.03160
# [196]	train-rmse:0.03416	eval-rmse:0.03160
# [197]	train-rmse:0.03416	eval-rmse:0.03160
# [198]	train-rmse:0.03416	eval-rmse:0.03160
# [199]	train-rmse:0.03416	eval-rmse:0.03160
# [200]	train-rmse:0.03416	eval-rmse:0.03160
# [201]	train-rmse:0.03415	eval-rmse:0.03160
# [202]	train-rmse:0.03415	eval-rmse:0.03160
# [203]	train-rmse:0.03415	eval-rmse:0.03160
# [204]	train-rmse:0.03415	eval-rmse:0.03160
# [205]	train-rmse:0.03415	eval-rmse:0.03160
# [206]	train-rmse:0.03415	eval-rmse:0.03160
# [207]	train-rmse:0.03415	eval-rmse:0.03159
# [208]	train-rmse:0.03415	eval-rmse:0.03159
# [209]	train-rmse:0.03415	eval-rmse:0.03159
# [210]	train-rmse:0.03415	eval-rmse:0.03159
# [211]	train-rmse:0.03415	eval-rmse:0.03159
# [212]	train-rmse:0.03415	eval-rmse:0.03159
# [213]	train-rmse:0.03415	eval-rmse:0.03159
# [214]	train-rmse:0.03415	eval-rmse:0.03159
# [215]	train-rmse:0.03415	eval-rmse:0.03159
# [216]	train-rmse:0.03415	eval-rmse:0.03159
# [217]	train-rmse:0.03415	eval-rmse:0.03159

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score

forecast = xgb_model.predict(dtest)
xgb_forecast = forecast.reshape(-1, 1)

xgb_forecast_inv = scaler_y.inverse_transform(xgb_forecast)

rmse_xgb = sqrt(mean_squared_error(y_test_inv, xgb_forecast_inv))
print('RMSE of hour-ahead electricity price XGBoost forecast: {}'
      .format(round(rmse_xgb, 3)))
# Out:
# RMSE of hour-ahead electricity price XGBoost forecast: 5.29

# %% [markdown]
# ## 2. LSTM

# %%
tf.keras.backend.clear_session()
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, TimeDistributed, Flatten, Dropout, RepeatVector

multivariate_lstm = tf.keras.models.Sequential([
    LSTM(100, input_shape=input_shape, 
         return_sequences=True),
    Flatten(),
    Dense(200, activation='relu'),
    Dropout(0.1),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_lstm.h5', monitor=('val_loss'), save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=6e-3, amsgrad=True)

multivariate_lstm.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_lstm.fit(train, epochs=120,
                                validation_data=validation,
                                callbacks=[early_stopping, 
                                           model_checkpoint])
# Out:
# Epoch 1/120
# 547/547 [==============================] - 14s 12ms/step - loss: 0.0109 - root_mean_squared_error: 0.0959 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0550
# Epoch 2/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0022 - root_mean_squared_error: 0.0470 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476
# Epoch 3/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0022 - root_mean_squared_error: 0.0465 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0456
# Epoch 4/120
# 547/547 [==============================] - 7s 13ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0474
# Epoch 5/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0020 - root_mean_squared_error: 0.0443 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0379
# Epoch 6/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0020 - root_mean_squared_error: 0.0445 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0433
# Epoch 7/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0019 - root_mean_squared_error: 0.0438 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0501
# Epoch 8/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0019 - root_mean_squared_error: 0.0438 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0367
# Epoch 9/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 10/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0020 - root_mean_squared_error: 0.0441 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# Epoch 11/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0434 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 12/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0368
# Epoch 13/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 14/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# Epoch 15/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0430 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0374
# Epoch 16/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0353
# Epoch 17/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0419- root_mean_squared_err
# Epoch 18/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 19/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0016 - root_mean_squared_error: 0.0400 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0339
# Epoch 20/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0379
# Epoch 21/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# Epoch 22/120
# 547/547 [==============================] - 8s 15ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0362
# Epoch 23/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0378 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 24/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0384
# Epoch 25/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 26/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# Epoch 27/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 28/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0380 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 29/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 30/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 9.6408e-04 - val_root_mean_squared_error: 0.0310
# Epoch 31/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0368 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0455
# Epoch 32/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 33/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0015 - root_mean_squared_error: 0.0393 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0389
# Epoch 34/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0350
# Epoch 35/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 36/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0014 - root_mean_squared_error: 0.0367 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0349
# Epoch 37/120
# 547/547 [==============================] - 6s 10ms/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 38/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0014 - root_mean_squared_error: 0.0369 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 39/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 40/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0014 - root_mean_squared_error: 0.0367 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0346

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_lstm = tf.keras.models.load_model('multivariate_lstm.h5')

forecast = multivariate_lstm.predict(X_test)
lstm_forecast = scaler_y.inverse_transform(forecast)

rmse_lstm = sqrt(mean_squared_error(y_test_inv,
                                    lstm_forecast))
print('RMSE of hour-ahead electricity price LSTM forecast: {}'
      .format(round(rmse_lstm, 3)))
# Out:
# RMSE of hour-ahead electricity price LSTM forecast: 5.155

# %% [markdown]
# ## Stacked LSTM

# %%
tf.keras.backend.clear_session()

multivariate_stacked_lstm = tf.keras.models.Sequential([
    LSTM(250, input_shape=input_shape, 
         return_sequences=True),
    LSTM(150, return_sequences=True),
    Flatten(),
    Dense(150, activation='relu'),
    Dropout(0.1),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_stacked_lstm.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=3e-3, amsgrad=True)

multivariate_stacked_lstm.compile(loss=loss,
                                  optimizer=optimizer,
                                  metrics=metric)

# %%
history = multivariate_stacked_lstm.fit(train, epochs=120,
                                validation_data=validation,
                                callbacks=[early_stopping, 
                                           model_checkpoint])
# Out:
# Epoch 1/120
# 547/547 [==============================] - 18s 18ms/step - loss: 0.0095 - root_mean_squared_error: 0.0740 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0499
# Epoch 2/120
# 547/547 [==============================] - 9s 17ms/step - loss: 0.0023 - root_mean_squared_error: 0.0480 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0475
# Epoch 3/120
# 547/547 [==============================] - 11s 20ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553
# Epoch 4/120
# 547/547 [==============================] - 10s 18ms/step - loss: 0.0022 - root_mean_squared_error: 0.0462 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0491
# Epoch 5/120
# 547/547 [==============================] - 10s 17ms/step - loss: 0.0021 - root_mean_squared_error: 0.0458 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0379
# Epoch 6/120
# 547/547 [==============================] - 10s 18ms/step - loss: 0.0020 - root_mean_squared_error: 0.0446 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444
# Epoch 7/120
# 547/547 [==============================] - 10s 18ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 8/120
# 547/547 [==============================] - 9s 17ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0471
# Epoch 9/120
# 547/547 [==============================] - 10s 18ms/step - loss: 0.0019 - root_mean_squared_error: 0.0438 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0339
# Epoch 10/120
# 547/547 [==============================] - 10s 17ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0390
# Epoch 11/120
# 547/547 [==============================] - 10s 18ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0436- loss: 0.0017 - root_mean_squared_error: 0 - ETA: 3s - loss - ETA: 0s - loss: 0.0018 - root_mean_squared_e
# Epoch 12/120
# 547/547 [==============================] - 9s 16ms/step - loss: 0.0018 - root_mean_squared_error: 0.0426 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 13/120
# 547/547 [==============================] - 9s 17ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420
# Epoch 14/120
# 547/547 [==============================] - 8s 15ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# Epoch 15/120
# 547/547 [==============================] - 9s 16ms/step - loss: 0.0017 - root_mean_squared_error: 0.0410 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 16/120
# 547/547 [==============================] - 9s 16ms/step - loss: 0.0016 - root_mean_squared_error: 0.0404 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 17/120
# 547/547 [==============================] - 9s 16ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_stacked_lstm = tf.keras.models.load_model('multivariate_stacked_lstm.h5')

forecast = multivariate_stacked_lstm.predict(X_test)
multivariate_stacked_lstm_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_stacked_lstm = sqrt(mean_squared_error(y_test_inv, 
                                                 multivariate_stacked_lstm_forecast))
print('RMSE of hour-ahead electricity price multivariate Stacked LSTM forecast: {}'
      .format(round(rmse_mult_stacked_lstm, 3)))
# Out:
# RMSE of hour-ahead electricity price multivariate Stacked LSTM forecast: 5.84

# %% [markdown]
# ## 1D CNN

# %%
tf.keras.backend.clear_session()

multivariate_cnn = tf.keras.models.Sequential([
    Conv1D(filters=48, kernel_size=2,
           strides=1, padding='causal',
           activation='relu', 
           input_shape=input_shape),
    Flatten(),
    Dense(48, activation='relu'),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_cnn.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=6e-3, amsgrad=True)

multivariate_cnn.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_cnn.fit(train, epochs=120,
                               validation_data=validation,
                               callbacks=[early_stopping, 
                                          model_checkpoint])
# Out:
# Epoch 1/120
# 547/547 [==============================] - 7s 7ms/step - loss: 0.0086 - root_mean_squared_error: 0.0703 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 2/120
# 547/547 [==============================] - 5s 8ms/step - loss: 0.0022 - root_mean_squared_error: 0.0464 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 3/120
# 547/547 [==============================] - 5s 9ms/step - loss: 0.0022 - root_mean_squared_error: 0.0466 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0398
# Epoch 4/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0505
# Epoch 5/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# Epoch 6/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0016 - root_mean_squared_error: 0.0405 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0350
# Epoch 7/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 8/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 9/120
# 547/547 [==============================] - 4s 6ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0357
# Epoch 10/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0388
# Epoch 11/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0382
# Epoch 12/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 13/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0424
# Epoch 14/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0362
# Epoch 15/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 16/120
# 547/547 [==============================] - 4s 7ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0385_squ
# Epoch 17/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 18/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420
# Epoch 19/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 20/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 21/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0013 - root_mean_squared_error: 0.0357 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 22/120
# 547/547 [==============================] - 3s 6ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0414

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_cnn = tf.keras.models.load_model('multivariate_cnn.h5')

forecast = multivariate_cnn.predict(X_test)
multivariate_cnn_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_cnn = sqrt(mean_squared_error(y_test_inv,
                                        multivariate_cnn_forecast))
print('RMSE of hour-ahead electricity price multivariate CNN forecast: {}'
      .format(round(rmse_mult_cnn, 3)))
# Out:
# RMSE of hour-ahead electricity price multivariate CNN forecast: 5.78

# %% [markdown]
# ## CNN-LSTM

# %%
tf.keras.backend.clear_session()

multivariate_cnn_lstm = tf.keras.models.Sequential([
    Conv1D(filters=100, kernel_size=2,
           strides=1, padding='causal',
           activation='relu', 
           input_shape=input_shape),
    LSTM(100, return_sequences=True),
    Flatten(),
    Dense(50, activation='relu'),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_cnn_lstm.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=4e-3, amsgrad=True)

multivariate_cnn_lstm.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_cnn_lstm.fit(train, epochs=120,
                                    validation_data=validation,
                                    callbacks=[early_stopping, 
                                               model_checkpoint])
# Out:
# Epoch 1/120
# 547/547 [==============================] - 12s 13ms/step - loss: 0.0069 - root_mean_squared_error: 0.0647 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0388
# Epoch 2/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0020 - root_mean_squared_error: 0.0442 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0449
# Epoch 3/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0456
# Epoch 4/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0389
# Epoch 5/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0019 - root_mean_squared_error: 0.0434 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 6/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 7/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0474
# Epoch 8/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0016 - root_mean_squared_error: 0.0400 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0339
# Epoch 9/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0014 - root_mean_squared_error: 0.0366 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 10/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0362
# Epoch 11/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0357
# Epoch 12/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 13/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0366
# Epoch 14/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 15/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0013 - root_mean_squared_error: 0.0357 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 16/120
# 547/547 [==============================] - 7s 13ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0378
# Epoch 17/120
# 547/547 [==============================] - 7s 13ms/step - loss: 0.0013 - root_mean_squared_error: 0.0362 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 18/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 19/120
# 547/547 [==============================] - 7s 13ms/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 20/120
# 547/547 [==============================] - 7s 14ms/step - loss: 0.0013 - root_mean_squared_error: 0.0354 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 21/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 22/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0011 - root_mean_squared_error: 0.0337 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0345
# Epoch 23/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0324
# Epoch 24/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# Epoch 25/120
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0011 - root_mean_squared_error: 0.0330 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0364
# Epoch 26/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 27/120
# 547/547 [==============================] - 7s 13ms/step - loss: 0.0010 - root_mean_squared_error: 0.0322 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 28/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0324
# Epoch 29/120
# 547/547 [==============================] - 6s 12ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# Epoch 30/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0011 - root_mean_squared_error: 0.0324 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 31/120
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0010 - root_mean_squared_error: 0.0322 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_cnn_lstm = tf.keras.models.load_model('multivariate_cnn_lstm.h5')

forecast = multivariate_cnn_lstm.predict(X_test)
multivariate_cnn_lstm_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_cnn_lstm = sqrt(mean_squared_error(y_test_inv, 
                                             multivariate_cnn_lstm_forecast))
print('RMSE of hour-ahead electricity price multivariate CNN-`LSTM forecast: {}'
      .format(round(rmse_mult_cnn_lstm, 3)))
# Out:
# RMSE of hour-ahead electricity price multivariate CNN-`LSTM forecast: 6.084

# %%
X_test.shape
# Out:
# (1812, 12, 5)

# %% [markdown]
# ## MLP

# %%
tf.keras.backend.clear_session()

multivariate_mlp = tf.keras.models.Sequential([
    TimeDistributed(Dense(200, activation='relu'),
                    input_shape=input_shape),
    TimeDistributed(Dense(150, activation='relu')),
    TimeDistributed(Dense(100, activation='relu')),
    TimeDistributed(Dense(50, activation='relu')),
    Flatten(),
    Dense(150, activation='relu'),
    Dropout(0.1),
    Dense(1)
])

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'multivariate_mlp.h5', save_best_only=True)
optimizer = tf.keras.optimizers.Adam(lr=2e-3, amsgrad=True)

multivariate_mlp.compile(loss=loss,
                          optimizer=optimizer,
                          metrics=metric)

# %%
history = multivariate_mlp.fit(train, epochs=120,
                               validation_data=validation,
                               callbacks=[early_stopping, 
                                          model_checkpoint])
# Out:
# Epoch 1/120
# 547/547 [==============================] - 6s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0546 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# Epoch 2/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0024 - root_mean_squared_error: 0.0492 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0508
# Epoch 3/120
# 547/547 [==============================] - 5s 8ms/step - loss: 0.0023 - root_mean_squared_error: 0.0478 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0421
# Epoch 4/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0024 - root_mean_squared_error: 0.0492 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0424
# Epoch 5/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0018 - root_mean_squared_error: 0.0428 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 6/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0376
# Epoch 7/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0445 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0399
# Epoch 8/120
# 547/547 [==============================] - 5s 8ms/step - loss: 0.0021 - root_mean_squared_error: 0.0455 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 9/120
# 547/547 [==============================] - 5s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0448 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 10/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0359
# Epoch 11/120
# 547/547 [==============================] - 4s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0430 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0354
# Epoch 12/120
# 547/547 [==============================] - 5s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0448
# Epoch 13/120
# 547/547 [==============================] - 5s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0443 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 14/120
# 547/547 [==============================] - 5s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0441 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0416
# Epoch 15/120
# 547/547 [==============================] - 4s 7ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0423

# %%
plot_model_rmse_and_loss(history)

# %%
multivariate_mlp = tf.keras.models.load_model('multivariate_mlp.h5')

forecast = multivariate_mlp.predict(X_test)
multivariate_mlp_forecast = scaler_y.inverse_transform(forecast)

rmse_mult_mlp = sqrt(mean_squared_error(y_test_inv,
                                        multivariate_mlp_forecast))
print('RMSE of hour-ahead electricity price multivariate MLP forecast: {}'
      .format(round(rmse_mult_mlp, 3)))
# Out:
# RMSE of hour-ahead electricity price multivariate MLP forecast: 5.318

# %% [markdown]
# ## Autoencoder

# %%
tf.keras.backend.clear_session()

encoder_decoder = tf.keras.models.Sequential([
    LSTM(50, activation='relu', input_shape=input_shape),
    RepeatVector(past_history),
    LSTM(50, activation='relu', return_sequences=True),
    TimeDistributed(Dense(50, activation='relu')),
    Flatten(),
    Dense(25, activation='relu'),
    Dense(1)
])



model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
                   'encoder_decoder.h5', save_best_only=True)

optimizer = tf.keras.optimizers.Adam(lr=1e-3, amsgrad=True)

encoder_decoder.compile(loss=loss,
                    optimizer=optimizer,
                    metrics=metric)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
history = encoder_decoder.fit(train, epochs=50,
                              validation_data=validation,
                              callbacks=[early_stopping, 
                                         model_checkpoint])
# Out:
# Epoch 1/50
# 547/547 [==============================] - 60s 99ms/step - loss: 0.0078 - root_mean_squared_error: 0.0691 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0519ss: 0.0080 - root
# Epoch 2/50
# 547/547 [==============================] - 50s 91ms/step - loss: 0.0025 - root_mean_squared_error: 0.0501 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 3/50
# 547/547 [==============================] - 53s 96ms/step - loss: 0.0020 - root_mean_squared_error: 0.0450 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530_
# Epoch 4/50
# 547/547 [==============================] - 49s 89ms/step - loss: 0.0022 - root_mean_squared_error: 0.0468 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0442
# Epoch 5/50
# 547/547 [==============================] - 50s 91ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0437
# Epoch 6/50
# 547/547 [==============================] - 52s 95ms/step - loss: 0.0019 - root_mean_squared_error: 0.0438 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0369
# Epoch 7/50
# 547/547 [==============================] - 50s 92ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 8/50
# 547/547 [==============================] - 55s 100ms/step - loss: 0.0017 - root_mean_squared_error: 0.0412 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 9/50
# 547/547 [==============================] - 48s 88ms/step - loss: 0.0017 - root_mean_squared_error: 0.0414 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0398
# Epoch 10/50
# 547/547 [==============================] - 47s 86ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 11/50
# 547/547 [==============================] - 47s 86ms/step - loss: 0.0017 - root_mean_squared_error: 0.0410 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# Epoch 12/50
# 547/547 [==============================] - 43s 79ms/step - loss: 0.0017 - root_mean_squared_error: 0.0409 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0364
# Epoch 13/50
# 547/547 [==============================] - 43s 78ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 14/50
# 547/547 [==============================] - 43s 78ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 15/50
# 547/547 [==============================] - 43s 78ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0374
# Epoch 16/50
# 547/547 [==============================] - 43s 78ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 17/50
# 547/547 [==============================] - 43s 79ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 18/50
# 547/547 [==============================] - 47s 85ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 19/50
# 547/547 [==============================] - 49s 90ms/step - loss: 0.0015 - root_mean_squared_error: 0.0390 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0382
# Epoch 20/50
# 547/547 [==============================] - 53s 97ms/step - loss: 0.0014 - root_mean_squared_error: 0.0375 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 21/50
# 547/547 [==============================] - 56s 102ms/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 22/50
# 547/547 [==============================] - 54s 99ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 23/50
# 547/547 [==============================] - 48s 87ms/step - loss: 0.0013 - root_mean_squared_error: 0.0362 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0448
# Epoch 24/50
# 547/547 [==============================] - 43s 79ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0339

# %%
plot_model_rmse_and_loss(history)

# %%
encoder_decoder = tf.keras.models.load_model('encoder_decoder.h5')

forecast = encoder_decoder.predict(X_test)
encoder_decoder_forecast = scaler_y.inverse_transform(forecast)

rmse_encoder_decoder = sqrt(mean_squared_error(y_test_inv, 
                                               encoder_decoder_forecast))
print('RMSE of hour-ahead electricity price Encoder-Decoder forecast: {}'
      .format(round(rmse_encoder_decoder, 3)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# RMSE of hour-ahead electricity price Encoder-Decoder forecast: 5.786

# %%
plt.figure(figsize=(20,10))
plt.plot(y_test_inv,label='ground true')
plt.plot(multivariate_mlp_forecast,label='forecast')
plt.title('Prediction vs. Test Value')
plt.legend()
